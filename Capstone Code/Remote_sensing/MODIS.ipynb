# %% [markdown]
# Source: https://modis.ornl.gov/data/modis_webservice.html

# %%
import requests
header = {'Accept': 'application/json'}

# Use following for a csv response:
# header = {'Accept': 'text/csv'}

response = requests.get(
    'https://modis.ornl.gov/rst/api/v1/MOD13Q1/subset?latitude=27.5&longitude=-80.5&startDate=A2018049&endDate=A2018049&kmAboveBelow=1&kmLeftRight=1', headers=header)
data = response.json()
print(response.json())
# Out:
# {'xllcorner': '-7940948.23', 'yllcorner': '3056937.34', 'cellsize': 231.656358264, 'nrows': 9, 'ncols': 9, 'band': 'all', 'latitude': 27.5, 'longitude': -80.5, 'header': 'https://modisrest.ornl.gov/rst/api/v1/MOD13Q1/subset?latitude=27.5&longitude=-80.5&startDate=A2018049&endDate=A2018049&kmAboveBelow=1&kmLeftRight=1', 'subset': [{'modis_date': 'A2018049', 'calendar_date': '2018-02-18', 'band': '250m_16_days_blue_reflectance', 'tile': 'h10v06', 'proc_date': '2018066164927', 'data': [237, 237, 237, 231, 231, 256, 256, 259, 259, 237, 237, 237, 231, 231, 256, 256, 259, 259, 269, 231, 231, 285, 285, 282, 282, 237, 237, 269, 231, 231, 285, 285, 282, 282, 237, 237, 250, 335, 335, 245, 245, 284, 284, 214, 214, 250, 335, 335, 245, 245, 284, 284, 214, 214, 298, 298, 298, 268, 268, 232, 232, 232, 232, 298, 298, 298, 268, 268, 232, 232, 232, 232, 310, 313, 313, 277, 277, 287, 287, 195, 195]}, {'modis_date': 'A2018049', 'calendar_date': '2018-02-18', 'band': '250m_16_days_MIR_reflectance', 'tile
# ...

# %%
data.keys()
# Out:
# dict_keys(['xllcorner', 'yllcorner', 'cellsize', 'nrows', 'ncols', 'band', 'latitude', 'longitude', 'header', 'subset'])
